# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=imperial"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng =  city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | badger
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | roma
# Processing Record 6 of Set 1 | olonkinbyen
# Processing Record 7 of Set 1 | beau vallon
# Processing Record 8 of Set 1 | port moresby
# Processing Record 9 of Set 1 | saipan
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | qingdao
# Processing Record 12 of Set 1 | howard springs
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | nadym
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 18 of Set 1 | bilibino
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | port mathurin
# Processing Record 21 of Set 1 | darwin
# Processing Record 22 of Set 1 | grytviken
# Processing Record 23 of Set 1 | palikir - national government center
# Processing Record 24 of Set 1 | fale old settlement
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | mumbwa
# Processing Record 28 of Set 1 | jipijapa
# Processing Record 29 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | estevan
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | adamstown
# Processing Record 34 of Set 1 | kiunga
# Processing Record 35 of Set 1 | badiyah
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | papatowai
# Processing Record 39 of Set 1 | atafu village
# Processing Record 40 of Set 1 | dakhla
# Processing Record 41 of Set 1 | sengkang
# Processing Record 42 of Set 1 | porto empedocle
# Processing Record 43 of Set 1 | port-aux-francais
# Processing Record 44 of Set 1 | anadyr
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | azemmour
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | tommot
# Processing Record 49 of Set 1 | vorgashor
# Processing Record 50 of Set 1 | baijiantan
# Processing Record 0 of Set 2 | lent'ekhi
# Processing Record 1 of Set 2 | gueltat zemmour
# City not found. Skipping...
# Processing Record 2 of Set 2 | amga
# Processing Record 3 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 2 | makarov
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | vilyuchinsk
# Processing Record 7 of Set 2 | likiep
# Processing Record 8 of Set 2 | katsuura
# Processing Record 9 of Set 2 | miramichi
# Processing Record 10 of Set 2 | west island
# Processing Record 11 of Set 2 | aasiaat
# Processing Record 12 of Set 2 | goba
# Processing Record 13 of Set 2 | nsanje
# Processing Record 14 of Set 2 | hacienda huancane
# Processing Record 15 of Set 2 | kimberley
# Processing Record 16 of Set 2 | chernyshevskiy
# Processing Record 17 of Set 2 | masterton
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | xiaoweizhai
# Processing Record 20 of Set 2 | margaret river
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | san-pedro
# Processing Record 23 of Set 2 | plesetsk
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | tanrake village
# City not found. Skipping...
# Processing Record 26 of Set 2 | hawaiian paradise park
# Processing Record 27 of Set 2 | inongo
# Processing Record 28 of Set 2 | axim
# Processing Record 29 of Set 2 | tadmur
# Processing Record 30 of Set 2 | vernon
# Processing Record 31 of Set 2 | kalajoki
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | belo sur tsiribihina
# Processing Record 34 of Set 2 | bubaque
# Processing Record 35 of Set 2 | hafnarfjordur
# Processing Record 36 of Set 2 | rio hato
# Processing Record 37 of Set 2 | maych'ew
# Processing Record 38 of Set 2 | howrah
# Processing Record 39 of Set 2 | illizi
# Processing Record 40 of Set 2 | juruti
# Processing Record 41 of Set 2 | garcia
# Processing Record 42 of Set 2 | puerto armuelles
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | sur
# Processing Record 45 of Set 2 | arkhangel'sk
# Processing Record 46 of Set 2 | krasnoufimsk
# Processing Record 47 of Set 2 | tofol
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | talnakh
# Processing Record 0 of Set 3 | weno
# Processing Record 1 of Set 3 | ingeniero jacobacci
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | tsiombe
# Processing Record 4 of Set 3 | juneau
# Processing Record 5 of Set 3 | northam
# Processing Record 6 of Set 3 | willowmore
# Processing Record 7 of Set 3 | udachny
# Processing Record 8 of Set 3 | whitehorse
# Processing Record 9 of Set 3 | wailua homesteads
# Processing Record 10 of Set 3 | metlili chaamba
# Processing Record 11 of Set 3 | qamdo
# Processing Record 12 of Set 3 | keflavik
# Processing Record 13 of Set 3 | utete
# Processing Record 14 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 3 | tucupita
# Processing Record 16 of Set 3 | zaragoza
# Processing Record 17 of Set 3 | igarka
# Processing Record 18 of Set 3 | benjamin aceval
# Processing Record 19 of Set 3 | detroit lakes
# Processing Record 20 of Set 3 | kristiansund
# Processing Record 21 of Set 3 | phrai bueng
# Processing Record 22 of Set 3 | isafjordur
# Processing Record 23 of Set 3 | susuman
# Processing Record 24 of Set 3 | klyuchi
# Processing Record 25 of Set 3 | tonj
# Processing Record 26 of Set 3 | lemvig
# Processing Record 27 of Set 3 | jiazi
# Processing Record 28 of Set 3 | bang saphan
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | edinburgh of the seven seas
# Processing Record 31 of Set 3 | emerald
# Processing Record 32 of Set 3 | vadso
# Processing Record 33 of Set 3 | mount isa
# Processing Record 34 of Set 3 | kuraymah
# Processing Record 35 of Set 3 | ambovombe
# Processing Record 36 of Set 3 | la'ie
# Processing Record 37 of Set 3 | kargopol'
# Processing Record 38 of Set 3 | vanimo
# Processing Record 39 of Set 3 | saint-girons
# Processing Record 40 of Set 3 | loukhi
# Processing Record 41 of Set 3 | macedo de cavaleiros
# Processing Record 42 of Set 3 | celestun
# Processing Record 43 of Set 3 | muriti
# Processing Record 44 of Set 3 | coquimbo
# Processing Record 45 of Set 3 | safotu
# Processing Record 46 of Set 3 | chyorny yar
# Processing Record 47 of Set 3 | mermoz boabab
# Processing Record 48 of Set 3 | inhambane
# Processing Record 49 of Set 3 | shalqar
# Processing Record 0 of Set 4 | enewetak
# Processing Record 1 of Set 4 | cambria
# Processing Record 2 of Set 4 | port lincoln
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | invercargill
# Processing Record 5 of Set 4 | severo-yeniseyskiy
# Processing Record 6 of Set 4 | yushu
# Processing Record 7 of Set 4 | sakakah
# Processing Record 8 of Set 4 | sheldon
# Processing Record 9 of Set 4 | mejit
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | beni saf
# Processing Record 12 of Set 4 | new plymouth
# Processing Record 13 of Set 4 | bel ombre
# Processing Record 14 of Set 4 | turinskaya sloboda
# Processing Record 15 of Set 4 | trinidad
# Processing Record 16 of Set 4 | akjoujt
# Processing Record 17 of Set 4 | finale ligure
# Processing Record 18 of Set 4 | stanley
# Processing Record 19 of Set 4 | tura
# Processing Record 20 of Set 4 | estrela
# Processing Record 21 of Set 4 | benguela
# Processing Record 22 of Set 4 | pangody
# Processing Record 23 of Set 4 | praia da vitoria
# Processing Record 24 of Set 4 | bezhetsk
# Processing Record 25 of Set 4 | lethem
# Processing Record 26 of Set 4 | nar'yan-mar
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | college
# Processing Record 29 of Set 4 | dudinka
# Processing Record 30 of Set 4 | coron
# Processing Record 31 of Set 4 | endasak
# Processing Record 32 of Set 4 | banjarmasin
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | mana
# Processing Record 35 of Set 4 | lubao
# Processing Record 36 of Set 4 | haiku-pauwela
# Processing Record 37 of Set 4 | gizo
# Processing Record 38 of Set 4 | kone
# Processing Record 39 of Set 4 | hastings
# Processing Record 40 of Set 4 | fukuecho
# Processing Record 41 of Set 4 | ar ruways
# Processing Record 42 of Set 4 | sinabang
# Processing Record 43 of Set 4 | lihue
# Processing Record 44 of Set 4 | pont rouge
# Processing Record 45 of Set 4 | quzhou
# Processing Record 46 of Set 4 | jayapura
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | afaahiti
# Processing Record 49 of Set 4 | harstad
# Processing Record 0 of Set 5 | conduaga
# Processing Record 1 of Set 5 | nacozari de garcia
# Processing Record 2 of Set 5 | kapit
# Processing Record 3 of Set 5 | acigne
# Processing Record 4 of Set 5 | papao
# Processing Record 5 of Set 5 | chonchi
# Processing Record 6 of Set 5 | saint-joseph
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | jimma
# Processing Record 9 of Set 5 | kahramanmaras
# Processing Record 10 of Set 5 | lalago
# Processing Record 11 of Set 5 | princeville
# Processing Record 12 of Set 5 | brisas de zicatela
# Processing Record 13 of Set 5 | masjed soleyman
# Processing Record 14 of Set 5 | nova sintra
# Processing Record 15 of Set 5 | ipilan
# Processing Record 16 of Set 5 | shindand
# Processing Record 17 of Set 5 | saint john
# Processing Record 18 of Set 5 | inarajan village
# Processing Record 19 of Set 5 | lakatoro
# Processing Record 20 of Set 5 | san antonio de pale
# Processing Record 21 of Set 5 | nyurba
# Processing Record 22 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 23 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 5 | uturoa
# Processing Record 25 of Set 5 | vilyuysk
# Processing Record 26 of Set 5 | zemio
# Processing Record 27 of Set 5 | mirnyy
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | port augusta
# Processing Record 30 of Set 5 | shimoda
# Processing Record 31 of Set 5 | ardabil
# Processing Record 32 of Set 5 | ust-nera
# Processing Record 33 of Set 5 | noumea
# Processing Record 34 of Set 5 | talara
# Processing Record 35 of Set 5 | nouadhibou
# Processing Record 36 of Set 5 | lovington
# Processing Record 37 of Set 5 | panacan
# Processing Record 38 of Set 5 | port douglas
# Processing Record 39 of Set 5 | qaqortoq
# Processing Record 40 of Set 5 | margate
# Processing Record 41 of Set 5 | arrifes
# Processing Record 42 of Set 5 | puerto ayora
# Processing Record 43 of Set 5 | port saint john's
# Processing Record 44 of Set 5 | kingston
# Processing Record 45 of Set 5 | lagunas
# Processing Record 46 of Set 5 | zhezqazghan
# Processing Record 47 of Set 5 | rybinsk
# Processing Record 48 of Set 5 | kapuskasing
# Processing Record 49 of Set 5 | sittwe
# Processing Record 0 of Set 6 | borger
# Processing Record 1 of Set 6 | alamos
# Processing Record 2 of Set 6 | tarakan
# Processing Record 3 of Set 6 | utrik
# Processing Record 4 of Set 6 | eastham
# Processing Record 5 of Set 6 | itaituba
# Processing Record 6 of Set 6 | barra do garcas
# Processing Record 7 of Set 6 | ravar
# Processing Record 8 of Set 6 | lamu
# Processing Record 9 of Set 6 | aban
# Processing Record 10 of Set 6 | ola
# Processing Record 11 of Set 6 | luganville
# Processing Record 12 of Set 6 | kirensk
# Processing Record 13 of Set 6 | tolanaro
# Processing Record 14 of Set 6 | kapa'a
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | holualoa
# Processing Record 17 of Set 6 | sinop
# Processing Record 18 of Set 6 | kavaratti
# Processing Record 19 of Set 6 | mar del plata
# Processing Record 20 of Set 6 | armacao de buzios
# Processing Record 21 of Set 6 | aykhal
# Processing Record 22 of Set 6 | tari
# Processing Record 23 of Set 6 | huarmey
# Processing Record 24 of Set 6 | backa topola
# Processing Record 25 of Set 6 | murzuq
# Processing Record 26 of Set 6 | vedaraniyam
# Processing Record 27 of Set 6 | punta del este
# Processing Record 28 of Set 6 | port alfred
# Processing Record 29 of Set 6 | geraldton
# Processing Record 30 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 6 | gusinoozyorsk
# Processing Record 32 of Set 6 | georgetown
# Processing Record 33 of Set 6 | fujin
# Processing Record 34 of Set 6 | sibiti
# Processing Record 35 of Set 6 | kafr takharim
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | palangkaraya
# Processing Record 38 of Set 6 | gambela
# Processing Record 39 of Set 6 | tchibanga
# Processing Record 40 of Set 6 | rio grande
# Processing Record 41 of Set 6 | nakamura
# Processing Record 42 of Set 6 | yuzhno-kurilsk
# Processing Record 43 of Set 6 | pitimbu
# Processing Record 44 of Set 6 | ad dawadimi
# Processing Record 45 of Set 6 | conception bay south
# Processing Record 46 of Set 6 | buala
# Processing Record 47 of Set 6 | ugurludag
# Processing Record 48 of Set 6 | fort bragg
# Processing Record 49 of Set 6 | nieuw amsterdam
# Processing Record 0 of Set 7 | mondlo
# Processing Record 1 of Set 7 | namibe
# Processing Record 2 of Set 7 | cide
# Processing Record 3 of Set 7 | suva
# Processing Record 4 of Set 7 | annaberg-buchholz
# Processing Record 5 of Set 7 | yangshuo
# Processing Record 6 of Set 7 | guerrero negro
# Processing Record 7 of Set 7 | puerto madero
# Processing Record 8 of Set 7 | gorazde
# Processing Record 9 of Set 7 | yima
# Processing Record 10 of Set 7 | broome
# Processing Record 11 of Set 7 | alaghsas
# Processing Record 12 of Set 7 | crane
# Processing Record 13 of Set 7 | benjamin constant
# Processing Record 14 of Set 7 | wanning
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | birobidzhan
# Processing Record 17 of Set 7 | richmond
# Processing Record 18 of Set 7 | jambi city
# Processing Record 19 of Set 7 | casablanca
# Processing Record 20 of Set 7 | tateyama
# Processing Record 21 of Set 7 | alofi
# Processing Record 22 of Set 7 | haldia
# Processing Record 23 of Set 7 | south hedland
# Processing Record 24 of Set 7 | an nuhud
# Processing Record 25 of Set 7 | long beach
# Processing Record 26 of Set 7 | marquette
# Processing Record 27 of Set 7 | lata
# Processing Record 28 of Set 7 | constantia
# Processing Record 29 of Set 7 | puerto baquerizo moreno
# Processing Record 30 of Set 7 | gore
# Processing Record 31 of Set 7 | shingu
# Processing Record 32 of Set 7 | eyl
# Processing Record 33 of Set 7 | hammerfest
# Processing Record 34 of Set 7 | collie
# Processing Record 35 of Set 7 | corbelia
# Processing Record 36 of Set 7 | vorkuta
# Processing Record 37 of Set 7 | hwange
# Processing Record 38 of Set 7 | keelung
# Processing Record 39 of Set 7 | posto fiscal rolim de moura
# Processing Record 40 of Set 7 | usogorsk
# Processing Record 41 of Set 7 | belomorsk
# Processing Record 42 of Set 7 | monticello
# Processing Record 43 of Set 7 | carazinho
# Processing Record 44 of Set 7 | tutoia
# Processing Record 45 of Set 7 | saynshand
# Processing Record 46 of Set 7 | khovd
# Processing Record 47 of Set 7 | kingscliff
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | winkler
# Processing Record 0 of Set 8 | anqiu
# Processing Record 1 of Set 8 | arauco
# Processing Record 2 of Set 8 | kudahuvadhoo
# Processing Record 3 of Set 8 | egilsstadir
# Processing Record 4 of Set 8 | tromso
# Processing Record 5 of Set 8 | mutuali
# Processing Record 6 of Set 8 | ballycastle
# Processing Record 7 of Set 8 | inirida
# Processing Record 8 of Set 8 | hit
# Processing Record 9 of Set 8 | chui
# Processing Record 10 of Set 8 | chibougamau
# Processing Record 11 of Set 8 | kyakhta
# Processing Record 12 of Set 8 | obudu
# Processing Record 13 of Set 8 | ancud
# Processing Record 14 of Set 8 | usinsk
# Processing Record 15 of Set 8 | glenwood springs
# Processing Record 16 of Set 8 | odder
# Processing Record 17 of Set 8 | tabou
# Processing Record 18 of Set 8 | guiyang
# Processing Record 19 of Set 8 | kalinkavichy
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 23 of Set 8 | balikpapan
# Processing Record 24 of Set 8 | anabar
# City not found. Skipping...
# Processing Record 25 of Set 8 | sydney
# Processing Record 26 of Set 8 | takoradi
# Processing Record 27 of Set 8 | kostomuksha
# Processing Record 28 of Set 8 | cottage grove
# Processing Record 29 of Set 8 | ciudad lazaro cardenas
# Processing Record 30 of Set 8 | mathis
# Processing Record 31 of Set 8 | puerto carreno
# Processing Record 32 of Set 8 | tazacorte
# Processing Record 33 of Set 8 | mount pearl
# Processing Record 34 of Set 8 | topchikha
# Processing Record 35 of Set 8 | magistral'nyy
# Processing Record 36 of Set 8 | tadine
# Processing Record 37 of Set 8 | st. john's
# Processing Record 38 of Set 8 | ostersund
# Processing Record 39 of Set 8 | maua
# Processing Record 40 of Set 8 | tual
# Processing Record 41 of Set 8 | gadzhiyevo
# Processing Record 42 of Set 8 | keokuk
# Processing Record 43 of Set 8 | morant bay
# Processing Record 44 of Set 8 | saldus
# Processing Record 45 of Set 8 | champerico
# Processing Record 46 of Set 8 | old town
# Processing Record 47 of Set 8 | tanki leendert
# City not found. Skipping...
# Processing Record 48 of Set 8 | las terrenas
# Processing Record 49 of Set 8 | kayangel
# Processing Record 0 of Set 9 | trincomalee
# Processing Record 1 of Set 9 | kulhudhuffushi
# Processing Record 2 of Set 9 | saudarkrokur
# Processing Record 3 of Set 9 | kitami
# Processing Record 4 of Set 9 | guskhara
# Processing Record 5 of Set 9 | okhotsk
# Processing Record 6 of Set 9 | zheleznogorsk
# Processing Record 7 of Set 9 | neryungri
# Processing Record 8 of Set 9 | la passe
# Processing Record 9 of Set 9 | greenville
# Processing Record 10 of Set 9 | westport
# Processing Record 11 of Set 9 | cidreira
# Processing Record 12 of Set 9 | bandarbeyla
# Processing Record 13 of Set 9 | fort-shevchenko
# Processing Record 14 of Set 9 | fisterra
# Processing Record 15 of Set 9 | al kharijah
# Processing Record 16 of Set 9 | isoka
# Processing Record 17 of Set 9 | barreiro do jaiba
# Processing Record 18 of Set 9 | nogliki
# Processing Record 19 of Set 9 | sola
# Processing Record 20 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 21 of Set 9 | tazovsky
# Processing Record 22 of Set 9 | dellys
# Processing Record 23 of Set 9 | rohatyn
# Processing Record 24 of Set 9 | phitsanulok
# Processing Record 25 of Set 9 | mahina
# Processing Record 26 of Set 9 | awjilah
# Processing Record 27 of Set 9 | east london
# Processing Record 28 of Set 9 | panaba
# Processing Record 29 of Set 9 | alice springs
# Processing Record 30 of Set 9 | queenstown
# Processing Record 31 of Set 9 | verkh-neyvinskiy
# Processing Record 32 of Set 9 | cedeira
# Processing Record 33 of Set 9 | barreirinhas
# Processing Record 34 of Set 9 | simanggang
# Processing Record 35 of Set 9 | bhadra
# Processing Record 36 of Set 9 | surskoye
# Processing Record 37 of Set 9 | tagab
# Processing Record 38 of Set 9 | rongelap
# Processing Record 39 of Set 9 | fiambala
# Processing Record 40 of Set 9 | minas de marcona
# Processing Record 41 of Set 9 | kangding
# Processing Record 42 of Set 9 | grand-lahou
# Processing Record 43 of Set 9 | mirpur sakro
# Processing Record 44 of Set 9 | tacoronte
# Processing Record 45 of Set 9 | picos
# Processing Record 46 of Set 9 | kupang
# Processing Record 47 of Set 9 | babu
# Processing Record 48 of Set 9 | senador jose porfirio
# Processing Record 49 of Set 9 | kitimat
# Processing Record 0 of Set 10 | ballina
# Processing Record 1 of Set 10 | cherepovets
# Processing Record 2 of Set 10 | portland
# Processing Record 3 of Set 10 | pangkalanbuun
# Processing Record 4 of Set 10 | fortuna
# Processing Record 5 of Set 10 | kununurra
# Processing Record 6 of Set 10 | borgetto
# Processing Record 7 of Set 10 | coahuayana de hidalgo
# Processing Record 8 of Set 10 | hongjiang
# Processing Record 9 of Set 10 | pierre
# Processing Record 10 of Set 10 | alta
# Processing Record 11 of Set 10 | serang
# Processing Record 12 of Set 10 | thunder bay
# Processing Record 13 of Set 10 | unai
# Processing Record 14 of Set 10 | varshets
# Processing Record 15 of Set 10 | kittila
# Processing Record 16 of Set 10 | malango
# Processing Record 17 of Set 10 | t'ongch'on-up
# Processing Record 18 of Set 10 | lautoka
# Processing Record 19 of Set 10 | saint-philippe
# Processing Record 20 of Set 10 | miri
# Processing Record 21 of Set 10 | soran
# Processing Record 22 of Set 10 | tinajo
# Processing Record 23 of Set 10 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 24 of Set 10 | ngama
# Processing Record 25 of Set 10 | peniche
# Processing Record 26 of Set 10 | hobyo
# Processing Record 27 of Set 10 | dno
# Processing Record 28 of Set 10 | ramnagar
# Processing Record 29 of Set 10 | san patricio
# Processing Record 30 of Set 10 | yemva
# Processing Record 31 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 32 of Set 10 | bermejo
# Processing Record 33 of Set 10 | krasnoural'sk
# Processing Record 34 of Set 10 | plastun
# Processing Record 35 of Set 10 | akureyri
# Processing Record 36 of Set 10 | orapa
# Processing Record 37 of Set 10 | nago
# Processing Record 38 of Set 10 | nizhneudinsk
# Processing Record 39 of Set 10 | lazaro cardenas
# Processing Record 40 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 41 of Set 10 | brezina
# Processing Record 42 of Set 10 | anori
# Processing Record 43 of Set 10 | bourg-saint-maurice
# Processing Record 44 of Set 10 | finspang
# Processing Record 45 of Set 10 | nicoya
# Processing Record 46 of Set 10 | funafuti
# Processing Record 47 of Set 10 | bundibugyo
# Processing Record 48 of Set 10 | at taj
# Processing Record 49 of Set 10 | karratha
# Processing Record 0 of Set 11 | hornostayivka
# Processing Record 1 of Set 11 | acarau
# Processing Record 2 of Set 11 | nanping
# Processing Record 3 of Set 11 | little cayman
# City not found. Skipping...
# Processing Record 4 of Set 11 | kukuna
# Processing Record 5 of Set 11 | rocha
# Processing Record 6 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 7 of Set 11 | aitape
# Processing Record 8 of Set 11 | salavan
# Processing Record 9 of Set 11 | abepura
# Processing Record 10 of Set 11 | chebarkul'
# Processing Record 11 of Set 11 | ghat
# Processing Record 12 of Set 11 | abdulino
# Processing Record 13 of Set 11 | tagta
# Processing Record 14 of Set 11 | yashkul'
# Processing Record 15 of Set 11 | iwanai
# Processing Record 16 of Set 11 | cockburn town
# Processing Record 17 of Set 11 | yinchuan
# Processing Record 18 of Set 11 | kasane
# Processing Record 19 of Set 11 | mandalgovi
# Processing Record 20 of Set 11 | muzayri'
# City not found. Skipping...
# Processing Record 21 of Set 11 | zouerate
# Processing Record 22 of Set 11 | el tigre
# Processing Record 23 of Set 11 | shymkent
# Processing Record 24 of Set 11 | sen monorom
# Processing Record 25 of Set 11 | toamasina
# Processing Record 26 of Set 11 | barentu
# Processing Record 27 of Set 11 | concordia
# Processing Record 28 of Set 11 | dawei
# Processing Record 29 of Set 11 | dunedin
# Processing Record 30 of Set 11 | sampit
# Processing Record 31 of Set 11 | selfoss
# Processing Record 32 of Set 11 | karachev
# Processing Record 33 of Set 11 | tongliao
# Processing Record 34 of Set 11 | ouani
# Processing Record 35 of Set 11 | arawa
# Processing Record 36 of Set 11 | colonia
# Processing Record 37 of Set 11 | madang
# Processing Record 38 of Set 11 | arno
# Processing Record 39 of Set 11 | kolosovka
# Processing Record 40 of Set 11 | hami
# Processing Record 41 of Set 11 | san juan de miraflores
# Processing Record 42 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 11 | st ives
# Processing Record 44 of Set 11 | sitia
# Processing Record 45 of Set 11 | yelizovo
# Processing Record 46 of Set 11 | whakatane
# Processing Record 47 of Set 11 | colby
# Processing Record 48 of Set 11 | sarmiento
# Processing Record 49 of Set 11 | hadibu
# Processing Record 0 of Set 12 | xinqing
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | jabat
# Processing Record 3 of Set 12 | puerto aysen
# Processing Record 4 of Set 12 | dana point
# Processing Record 5 of Set 12 | bengkulu
# Processing Record 6 of Set 12 | pursat
# Processing Record 7 of Set 12 | kirakira
# Processing Record 8 of Set 12 | champoton
# Processing Record 9 of Set 12 | washington
# Processing Record 10 of Set 12 | woodfin
# Processing Record 11 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 12 of Set 12 | nadi
# Processing Record 13 of Set 12 | ammon
# Processing Record 14 of Set 12 | santana
# Processing Record 15 of Set 12 | narva
# Processing Record 16 of Set 12 | kerikeri
# Processing Record 17 of Set 12 | dalandzadgad
# Processing Record 18 of Set 12 | arteche
# Processing Record 19 of Set 12 | the pas
# Processing Record 20 of Set 12 | taperoa
# Processing Record 21 of Set 12 | busselton
# Processing Record 22 of Set 12 | banda aceh
# Processing Record 23 of Set 12 | fort mcmurray
# Processing Record 24 of Set 12 | west torrington
# Processing Record 25 of Set 12 | loango
# Processing Record 26 of Set 12 | castillos
# Processing Record 27 of Set 12 | cobija
# Processing Record 28 of Set 12 | kruisfontein
# Processing Record 29 of Set 12 | onega
# Processing Record 30 of Set 12 | ilukste
# Processing Record 31 of Set 12 | tarawa
# Processing Record 32 of Set 12 | hithadhoo
# Processing Record 33 of Set 12 | mazamari
# Processing Record 34 of Set 12 | ternate
# Processing Record 35 of Set 12 | shimabara
# Processing Record 36 of Set 12 | bodaybo
# Processing Record 37 of Set 12 | tra vinh
# Processing Record 38 of Set 12 | mount gambier
# Processing Record 39 of Set 12 | winchester
# Processing Record 40 of Set 12 | manokwari
# Processing Record 41 of Set 12 | velez rubio
# Processing Record 42 of Set 12 | buka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness
# 0          badger  64.8000 -147.5333     72.00        33          75  \
# 1  puerto natales -51.7236  -72.4875     32.59        91          98
# 2     yellowknife  62.4560 -114.3525     57.72        54          40
# 3        waitangi -43.9535 -176.5597     57.81        85           7
# 4            roma  43.2128  -75.4557     63.52        47           0
#
#    Wind Speed Country        Date
# 0        5.75      US  1685051598
# 1        5.48      CL  1685051598
# 2        9.22      CA  1685051598
# 3        4.00      NZ  1685051598
# 4        7.00      US  1685051396

# %%
import os

# Create the output_data directory if it doesn't exist
os.makedirs("output_data", exist_ok=True)
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0                badger  64.8000 -147.5333     72.00        33          75  \
# 1        puerto natales -51.7236  -72.4875     32.59        91          98
# 2           yellowknife  62.4560 -114.3525     57.72        54          40
# 3              waitangi -43.9535 -176.5597     57.81        85           7
# 4                  roma  43.2128  -75.4557     63.52        47           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1685051598
# 1              5.48      CL  1685051598
# 2              9.22      CA  1685051598
# 3              4.00      NZ  1685051598
# 4              7.00      US  1685051396

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", alpha=0.75)


# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", alpha=0.75)



# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Calculate the regression line
    regress_values = x_values * slope + intercept

    # Create the scatter plot
    plt.scatter(x_values, y_values)

    # Plot the regression line
    plt.plot(x_values, regress_values, color='red')

    # Annotate the equation of the line and the r-value
    equation = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
    r_value = f'R-value = {round(rvalue, 2)}'
    plt.annotate(equation, (x_values.min(), y_values.min()), fontsize=12, color='red')
    plt.annotate(r_value, (x_values.min(), y_values.min() + 5), fontsize=12, color='red')

    # Set the title and labels
    plt.title(f'{hemisphere}: {x_label} vs. {y_label}')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Save the figure
    plt.savefig(f'output_data/{hemisphere}_{x_label.replace(" ", "")}_{y_label.replace(" ", "")}_linear_regression.png')

    # Show the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 0             badger  64.8000 -147.5333     72.00        33          75  \
# 2        yellowknife  62.4560 -114.3525     57.72        54          40
# 4               roma  43.2128  -75.4557     63.52        47           0
# 5        olonkinbyen  70.9221   -8.7187     30.54        63          42
# 8             saipan  15.1355  145.7010     83.64       100          75
#
#          Wind Speed Country        Date
# City_ID
# 0              5.75      US  1685051598
# 2              9.22      CA  1685051598
# 4              7.00      US  1685051396
# 5             23.51      SJ  1685051599
# 8             18.41      MP  1685051599

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness
# City_ID
# 1        puerto natales -51.7236  -72.4875     32.59        91          98  \
# 3              waitangi -43.9535 -176.5597     57.81        85           7
# 6           beau vallon -20.4189   57.6953     72.21        82          85
# 7          port moresby  -9.4431  147.1797     74.62        94         100
# 9            bredasdorp -34.5322   20.0403     49.17        84          62
#
#          Wind Speed Country        Date
# City_ID
# 1              5.48      CL  1685051598
# 3              4.00      NZ  1685051598
# 6             15.75      MU  1685051599
# 7              5.75      PG  1685051525
# 9              9.78      ZA  1685051600

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere: Temperature vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")

# Add equation to the plot
plt.text(0, 30, line_eq, fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Linear Regression: Northern Hemisphere\nTemperature vs. Latitude")

# Print r-value
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_data/Northern_Hemisphere_Temperature_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# The r-value is: -0.8033689427908083

# %%
# Perform linear regression on Southern Hemisphere: Temperature vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")

# Annotate the line equation
plt.annotate(line_eq, (-50, 80), fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("Linear Regression: Southern Hemisphere\nTemperature vs. Latitude")

# Print r-value
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_data/Southern_Hemisphere_Temperature_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7864133488484397

# %% [markdown]
# **Discussion about the linear relationship: For the Temperature vs. Latitude relationship in the Northern Hemisphere, the obtained equation of the regression line is y = -0.66x + 89.97. The high absolute value of the r-value (-0.803) indicates a strong negative correlation between temperature and latitude in the Northern Hemisphere. This means that as latitude increases, there is a clear tendency for temperature to decrease. The negative slope of the regression line supports this observation.
#
# In contrast, for the Temperature vs. Latitude relationship in the Southern Hemisphere, the obtained equation of the regression line is y = 0.71x + 82.23. The high absolute value of the r-value (0.786) suggests a strong positive correlation. This indicates that as latitude increases in the Southern Hemisphere, there is a clear tendency for temperature to also increase. The positive slope of the regression line supports this observation.
#
# These strong correlations between temperature and latitude in both hemispheres suggest that latitude plays a significant role in determining temperature variations. As one moves away from the equator (higher latitudes), the temperature tends to decrease in the Northern Hemisphere and increase in the Southern Hemisphere. This can be attributed to the variations in solar radiation and the angle at which sunlight reaches the Earth's surface at different latitudes.
#
# It is important to note that while latitude is an influential factor, other variables such as altitude, ocean currents, and local geographical features can also contribute to temperature variations.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere: Humidity vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")

# Add equation to the plot
plt.text(40, 10, line_eq, fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Linear Regression: Northern Hemisphere\nHumidity vs. Latitude")

# Print r-value
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_data/Northern_Hemisphere_Humidity_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# The r-value is: -0.06619971525132447

# %%
# Perform linear regression on Southern Hemisphere: Humidity vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate regression line values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r-")

# Add equation to the plot
plt.text(-50, 30, line_eq, fontsize=15, color="red")

# Set labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Linear Regression: Southern Hemisphere\nHumidity vs. Latitude")

# Print r-value
print(f"The r-value is: {rvalue}")

# Save the figure
plt.savefig("output_data/Southern_Hemisphere_Humidity_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.15181125674249266

# %% [markdown]
# **Discussion about the linear relationship:
# For the Temperature vs. Latitude relationship in the Northern Hemisphere, the obtained equation of the regression line is y = -0.66x + 89.97. The calculated r-value of -0.066 suggests a very weak negative correlation between temperature and latitude in the Northern Hemisphere. This means that there is a slight tendency for temperature to decrease slightly as latitude increases, but the relationship is not significant.
#
# On the other hand, for the Temperature vs. Latitude relationship in the Southern Hemisphere, the obtained equation of the regression line is y = 0.71x + 82.23. The calculated r-value of 0.151 indicates a weak positive correlation. This suggests a slight tendency for temperature to increase slightly as latitude increases in the Southern Hemisphere, but again, the relationship is not very strong.
#
# It is important to note that the r-values for both cases are very close to zero, indicating that latitude alone does not have a strong influence on temperature. Other factors such as altitude, ocean currents, and local weather patterns are likely more significant in determining temperature variations.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Perform linear regression for cloudiness vs. latitude in the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Calculate the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create the scatter plot
plt.scatter(x_values, y_values)

# Plot the regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation on the graph
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_values.min(), y_values.min()), fontsize=15, color="red")

# Add labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere: Cloudiness vs. Latitude Linear Regression")
# Print r-value
print(f"The r-value is: {rvalue}")
# Save the figure
plt.savefig("output_data/Northern_Hemisphere_Cloudiness_vs_Latitude.png")

# Show the plot
plt.show()
# Out:
# The r-value is: -0.056638975059233425

# %%
# Perform linear regression for cloudiness vs. latitude in the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Calculate the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Create the scatter plot
plt.scatter(x_values, y_values)

# Plot the regression line
plt.plot(x_values, regress_values, "r")

# Annotate the equation on the graph
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_values.min(), y_values.min()), fontsize=15, color="red")

# Add labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere: Cloudiness vs. Latitude Linear Regression")
# Print r-value
print(f"The r-value is: {rvalue}")
# Save the figure
plt.savefig("output_data/Southern_Hemisphere_Cloudiness_vs_Latitude.png")

# Show the plot
plt.show()
# Out:
# The r-value is: 0.044986703285600074

# %% [markdown]
# **Discussion about the linear relationship:** For the Cloudiness vs. Latitude relationship in the Northern Hemisphere, the obtained equation of the regression line is y = -0.11x + 60.05. The calculated r-value of -0.056 suggests a very weak negative correlation between cloudiness and latitude in the Northern Hemisphere. This means that there is a slight tendency for cloudiness to decrease slightly as latitude increases, but the relationship is not significant.
#
# Similarly, for the Cloudiness vs. Latitude relationship in the Southern Hemisphere, the obtained equation of the regression line is y = 0.12x + 53.22. The calculated r-value of 0.044 indicates a very weak positive correlation. This suggests a slight tendency for cloudiness to increase slightly as latitude increases in the Southern Hemisphere, but again, the relationship is not significant.
#
# In both cases, the r-values are close to zero, indicating that latitude alone does not have a strong influence on cloudiness. Other factors and variables likely play a more significant role in determining cloudiness levels.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere data for Wind Speed vs. Latitude
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate the regression line values
regress_values = x_values * slope + intercept

# Create the scatter plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')

# Set the plot title, xlabel, and ylabel
plt.title("Northern Hemisphere: Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print the equation of the line on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (10, 25), fontsize=15, color='red')
# Print r-value
print(f"The r-value is: {rvalue}")
# Save the figure
plt.savefig("output_data/Northern_Hemisphere_Wind_Speed_vs_Latitude.png")

# Show the plot
plt.show()
# Out:
# The r-value is: 0.024057853012919902

# %%
# Perform linear regression on Southern Hemisphere data for Wind Speed vs. Latitude
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Calculate the regression line values
regress_values = x_values * slope + intercept

# Create the scatter plot
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')

# Set the plot title, xlabel, and ylabel
plt.title("Southern Hemisphere: Wind Speed vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Print the equation of the line on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (-50, 20), fontsize=15, color='red')
# Print r-value
print(f"The r-value is: {rvalue}")
# Save the figure
plt.savefig("output_data/Southern_Hemisphere_Wind_Speed_vs_Latitude.png")

# Show the plot
plt.show()
# Out:
# The r-value is: -0.2922373344756815

# %% [markdown]
# **Discussion about the linear relationship:** For the Wind Speed vs. Latitude relationship in the Northern Hemisphere, the obtained r-value of 0.024 indicates a very weak positive correlation. The equation of the regression line, y = 0.01x + 8.07, suggests that there is a slight increase in wind speed as latitude increases, but the relationship is not significant.
#
# In contrast, for the Wind Speed vs. Latitude relationship in the Southern Hemisphere, the obtained r-value of -0.292 indicates a weak negative correlation. The equation of the regression line, y = -0.11x + 5.63, suggests that there is a slight decrease in wind speed as latitude increases in the Southern Hemisphere. However, like in the Northern Hemisphere, the relationship is not very strong.
#
# It's important to note that in both cases, the r-values are quite low, indicating that latitude alone does not explain a significant portion of the variation in wind speed. Other factors and variables may have a more dominant influence on wind speed.
